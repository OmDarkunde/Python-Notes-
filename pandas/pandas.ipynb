# %% [markdown]
# > ###  pip --- Preferred Installer Program

# %% [markdown]
# > # pandas

# %% [markdown]
# > ### the data in pandas are of two types
#     + series
#     + datafreamce

# %% [markdown]
# ### column name can ve changed with dataframe[name_to_convert ,column = ["give here names"]]

# %%
import pandas as pd

# %%
data = ["apple", "banana" ,"oranges" ,"kiwi"]

# %% [markdown]
# > ## series data

# %%
# empty series 
empty = pd.Series()
empty
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1484\3850164451.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   empty = pd.Series()
# Series([], dtype: float64)

# %%
series_data = pd.Series(data)

# %%
series_data
# Out:
# 0      apple
# 1     banana
# 2    oranges
# 3       kiwi
# dtype: object

# %%
type(series_data)
# Out:
# pandas.core.series.Series

# %%
day = [ "monday", "tuesday" ,"thursday", "friday", "saturday"]

# %%
ser_day = pd.Series(day)

# %%
ser_day
# Out:
# 0      monday
# 1     tuesday
# 2    thursday
# 3      friday
# 4    saturday
# dtype: object

# %%
ser_day[4]
# Out:
# 'saturday'

# %% [markdown]
# > # data frame
#          2 dimensional data structure

# %%
#empty 
df = pd.DataFrame()
print(df)
# col =rows 
# index = col
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data2 = {"calories" :[120, 300, 240],
         "duration" :[60, 120, 80]}

# %%
df = pd.DataFrame(data) 
print(df)
# Out:
#          0
# 0    apple
# 1   banana
# 2  oranges
# 3     kiwi

# %% [markdown]
# > ### to give name to the column

# %%
df = pd.DataFrame(data , columns=["fruits"])  
print(df)
# Out:
#     fruits
# 0    apple
# 1   banana
# 2  oranges
# 3     kiwi

# %% [markdown]
# > ### Give name to the rows

# %%
df = pd.DataFrame(data , index=["fruit1" , "fruit2" ,"fruit3" , "fruit4"])  
print(df)
# Out:
#               0
# fruit1    apple
# fruit2   banana
# fruit3  oranges
# fruit4     kiwi

# %% [markdown]
# > ### both combined  __rows+ col__
#
# + __column__ --> columns
# + __rows__ --> index

# %%
df = pd.DataFrame(data ,columns=["fruits"], index=["fruit1" , "fruit2" ,"fruit3" , "fruit4"])  
print(df)
# Out:
#        fruits
# fruit1    NaN
# fruit2    NaN
# fruit3    NaN
# fruit4    NaN

# %% [markdown]
# > # convert the dictonary into data frame

# %%
data = { "car" : ["bmw" , "rols royal" , "honda"] ,
        "years" : [3,4,2]}

# %%
df1 =pd.DataFrame(data)
df1
# Out:
#           car  years
# 0         bmw      3
# 1  rols royal      4
# 2       honda      2

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # examples

# %%
age = [ 10,20,15,25,27]
ag_series = pd.Series(age)
ag_series
# Out:
# 0    10
# 1    20
# 2    15
# 3    25
# 4    27
# dtype: int64

# %%
data = {"day1" : 400, "day2" : 450 , "day3" : 1500}
seri22 = pd.Series(data)
print(seri22)

# keys are in interger because of that reasin dtype is in int64
# Out:
# day1     400
# day2     450
# day3    1500
# dtype: int64

# %%
df1
# Out:
#           car  years
# 0         bmw      3
# 1  rols royal      4
# 2       honda      2

# %% [markdown]
# > __imp__

# %% [markdown]
# > # info
#     to cheak the information of data frame

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   car     3 non-null      object
#  1   years   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %% [markdown]
# > # __loc__ , __iloc__
#     loc -- is the information of the row
#     iloc  -- > is the information of the column

# %%
df1
# Out:
#           car  years
# 0         bmw      3
# 1  rols royal      4
# 2       honda      2

# %%
df1.loc[[1,2]]
# Out:
#           car  years
# 1  rols royal      4
# 2       honda      2

# %%
df1.loc[[0,2]]
# Out:
#      car  years
# 0    bmw      3
# 2  honda      2

# %% [markdown]
# # __iloc__

# %%
data = {"calories" : [120,300,240], 
"duration" : [60,120,80]}

# %%
df = pd.DataFrame(data , index= ["day1" , "day2" ,"day3"])
df
# Out:
#       calories  duration
# day1       120        60
# day2       300       120
# day3       240        80

# %%
df.iloc[[0]]
# Out:
#       calories  duration
# day1       120        60

# %% [markdown]
# > # read files from device

# %% [markdown]
# # crtl + shift + c  --- > to copy path

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\user\Downloads\Companies.csv")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                611,289           6.7%  2,100,000  Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 2                413,680          44.8%     62,000          Spring, Texas
# 3                394,328           7.8%    164,000  Cupertino, California
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %% [markdown]
# ## __loc__
# ###  rows slicing the data frame

# %%
df.loc[[1,4]] # slicing data frame
# Out:
#    Rank                Name                    Industry  \
# 1     2              Amazon  Retail and cloud computing
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %%
df[::] # data set
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df[::-1] # reverse data
# Out:
#     Rank                      Name                    Industry  \
# 99   100                  Qualcomm                  Technology
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 97    98           United Airlines                     Airline
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 95    96                  Best Buy                      Retail
# ..   ...                       ...                         ...
# 4      5        UnitedHealth Group                  Healthcare
# 3      4                     Apple        Electronics industry
# 2      3                ExxonMobil          Petroleum industry
# 1      2                    Amazon  Retail and cloud computing
# 0      1                   Walmart                      Retail
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 99                 44,200          31.7%     51,000    San Diego, California
# ...

# %% [markdown]
# > ### __df.iloc["row number" , "col number"]__

# %%
# df.iloc["row number" , "column index "]
df.iloc[1,1]
# Out:
# 'Amazon'

# %%
df1
# Out:
#           car  years
# 0         bmw      3
# 1  rols royal      4
# 2       honda      2

# %%
df1.iloc[1,1]
# Out:
# 4

# %%
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %% [markdown]
# we need first for names and industry only

# %% [markdown]
# > ### __df.iloc["row number" , "col number"]__

# %%
df.iloc[0:4, 1:3]
# Out:
#          Name                    Industry
# 0     Walmart                      Retail
# 1      Amazon  Retail and cloud computing
# 2  ExxonMobil          Petroleum industry
# 3       Apple        Electronics industry

# %%
df.iloc[1,2]
# Out:
# 'Retail and cloud computing'

# %%
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %% [markdown]
# > ### indexing(start , end+1 )

# %%
df.iloc[0:3,1:3]
# Out:
#          Name                    Industry
# 0     Walmart                      Retail
# 1      Amazon  Retail and cloud computing
# 2  ExxonMobil          Petroleum industry

# %%
df.info(  )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    100 non-null    int64
#  1   Name                    100 non-null    object
#  2   Industry                100 non-null    object
#  3   Revenue (USD millions)  100 non-null    object
#  4   Revenue growth          100 non-null    object
#  5   Employees               100 non-null    object
#  6   Headquarters            100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %% [markdown]
# > # head
#     disply the first  5 recods from the start
#     default 5 is set
#     we can change the count also

# %%
df.head(7)
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
# 5     6          CVS Health                  Healthcare
# 6     7  Berkshire Hathaway                Conglomerate
#
#   Revenue (USD millions) Revenue growth  Employees              Headquarters
# 0                611,289           6.7%  2,100,000     Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000       Seattle, Washington
# 2                413,680          44.8%     62,000             Spring, Texas
# 3                394,328           7.8%    164,000     Cupertino, California
# 4                324,162          12.7%    400,000     Minnetonka, Minnesota
# ...

# %% [markdown]
# > # tail
#     shows the last 5 rows
#     default 5 is set
#     we can change the count also

# %%
df.tail(7)
# Out:
#     Rank                      Name                 Industry  \
# 93    94                PBF Energy       Petroleum industry
# 94    95                      Nike                  Apparel
# 95    96                  Best Buy                   Retail
# 96    97      Bristol-Myers Squibb  Pharmaceutical industry
# 97    98           United Airlines                  Airline
# 98    99  Thermo Fisher Scientific   Laboratory instruments
# 99   100                  Qualcomm               Technology
#
#    Revenue (USD millions) Revenue growth Employees  \
# 93                 46,830          71.8%     3,616
# 94                 46,710           4.9%    79,100
# 95                 46,298          10.6%    71,100
# 96                 46,159           0.5%    34,300
# 97                 44,955          82.5%    92,795
# 98                 44,915          14.5%   130,000
# 99                 44,200          31.7%    51,000
#
#                          Headquarters
# ...

# %% [markdown]
# > # to_string
#      to print every thing in string format

# %%
df.to_string()
# Out:
# "    Rank                                 Name                            Industry Revenue (USD millions) Revenue growth  Employees                                Headquarters\n0      1                              Walmart                              Retail                611,289           6.7%  2,100,000                       Bentonville, Arkansas\n1      2                               Amazon          Retail and cloud computing                513,983           9.4%  1,540,000                         Seattle, Washington\n2      3                           ExxonMobil                  Petroleum industry                413,680          44.8%     62,000                               Spring, Texas\n3      4                                Apple                Electronics industry                394,328           7.8%    164,000                       Cupertino, California\n4      5                   UnitedHealth Group                          Healthcare                324,162          12.
# ...

# %%
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %% [markdown]
# > # describe

# %%
df.describe()
# Out:
#              Rank
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %% [markdown]
# > # isnull

# %%
df.isnull() # it gives the truw false format
# Out:
#      Rank   Name  Industry  Revenue (USD millions)  Revenue growth  Employees  \
# 0   False  False     False                   False           False      False
# 1   False  False     False                   False           False      False
# 2   False  False     False                   False           False      False
# 3   False  False     False                   False           False      False
# 4   False  False     False                   False           False      False
# ..    ...    ...       ...                     ...             ...        ...
# 95  False  False     False                   False           False      False
# 96  False  False     False                   False           False      False
# 97  False  False     False                   False           False      False
# 98  False  False     False                   False           False      False
# 99  False  False     False                   False           False      False
#
#     Headquarters
# ...

# %%
df.isnull().sum()
# Out:
# Rank                      0
# Name                      0
# Industry                  0
# Revenue (USD millions)    0
# Revenue growth            0
# Employees                 0
# Headquarters              0
# dtype: int64

# %% [markdown]
# > # dropna -->
#     it will emove the null values from the data set

# %%
df.dropna()
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %% [markdown]
# > # replace with original data

# %%
df= df.dropna()

# %%
df.dropna(inplace=True)

# %% [markdown]
# > # fillna -
#     if large amount of data has na values then we nned to replace them for that we will use the fillna

# %%
df.fillna("a")
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %% [markdown]
# > ## column

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Industry', 'Revenue (USD millions)', 'Revenue growth',
#        'Employees', 'Headquarters'],
#       dtype='object')

# %% [markdown]
#  > # Duplicate

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %% [markdown]
# > # drop the duplicate values

# %%
df.drop_duplicates()
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %% [markdown]
#  > # [] -- > gives series and [[]] ---> gives the data freame

# %%
t = df["Name"]

# %%
y = df[["Name"]]

# %%
type(t)
# Out:
# pandas.core.series.Series

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# > # reset_index()
#
# inplace=True

# %%
df = df.reset_index()

# %%
df
# Out:
#     index  Rank                      Name                    Industry  \
# 0       0     1                   Walmart                      Retail
# 1       1     2                    Amazon  Retail and cloud computing
# 2       2     3                ExxonMobil          Petroleum industry
# 3       3     4                     Apple        Electronics industry
# 4       4     5        UnitedHealth Group                  Healthcare
# ..    ...   ...                       ...                         ...
# 95     95    96                  Best Buy                      Retail
# 96     96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97     97    98           United Airlines                     Airline
# 98     98    99  Thermo Fisher Scientific      Laboratory instruments
# 99     99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# ...

# %% [markdown]
# # drop
#     axis  = 1 ----> column
#     axis = 0 --- > row
#
#     by default axis is  0

# %%
# columm 
df.drop("index" ,axis=1, inplace=True)

# %%
# row 
df.drop(0)
# Out:
#     Rank                      Name                    Industry  \
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# 5      6                CVS Health                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees              Headquarters
# 1                 513,983           9.4%  1,540,000       Seattle, Washington
# ...

# %%
df.drop(1)
# Out:
#     Rank                      Name                 Industry  \
# 0      1                   Walmart                   Retail
# 2      3                ExxonMobil       Petroleum industry
# 3      4                     Apple     Electronics industry
# 4      5        UnitedHealth Group               Healthcare
# 5      6                CVS Health               Healthcare
# ..   ...                       ...                      ...
# 95    96                  Best Buy                   Retail
# 96    97      Bristol-Myers Squibb  Pharmaceutical industry
# 97    98           United Airlines                  Airline
# 98    99  Thermo Fisher Scientific   Laboratory instruments
# 99   100                  Qualcomm               Technology
#
#    Revenue (USD millions) Revenue growth  Employees              Headquarters
# 0                 611,289           6.7%  2,100,000     Bentonville, Arkansas
# 2                 413,680          44.8%     62,000             Spring, Texas
# ...

# %% [markdown]
# ## companies whoes rank is below  10

# %%
df[df.Rank < 10]
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...

# %% [markdown]
# ## delet the index number  10

# %%
df.drop(df[df["Rank"] == 10 ],axis = ) # this will generate the data frame because we can do this
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df.drop(df[df["Rank"] == 10 ])
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df1 = df[df["Rank"] == 10 ]

# %%
df1.loc[:]
# Out:
#    Rank                 Name            Industry Revenue (USD millions)  \
# 9    10  Chevron Corporation  Petroleum industry                246,252
#
#   Revenue growth Employees           Headquarters
# 9          51.6%    43,846  San Ramon, California

# %% [markdown]
# > ### find the index

# %%
df[df["Name"] == "Amazon"]
# Out:
#    Rank    Name                    Industry Revenue (USD millions)  \
# 1     2  Amazon  Retail and cloud computing                513,983
#
#   Revenue growth  Employees         Headquarters
# 1           9.4%  1,540,000  Seattle, Washington

# %% [markdown]
# > # convert pandas data into pandas

# %%
array = df.to_numpy()

# %%
array
# Out:
# array([[1, 'Walmart', 'Retail', '611,289', '6.7%', '2,100,000',
#         'Bentonville, Arkansas'],
#        [2, 'Amazon', 'Retail and cloud computing', '513,983', '9.4%',
#         '1,540,000', 'Seattle, Washington'],
#        [3, 'ExxonMobil', 'Petroleum industry', '413,680', '44.8%',
#         '62,000', 'Spring, Texas'],
#        [4, 'Apple', 'Electronics industry', '394,328', '7.8%', '164,000',
#         'Cupertino, California'],
#        [5, 'UnitedHealth Group', 'Healthcare', '324,162', '12.7%',
#         '400,000', 'Minnetonka, Minnesota'],
#        [6, 'CVS Health', 'Healthcare', '322,467', '10.4%', '259,500',
#         'Woonsocket, Rhode Island'],
#        [7, 'Berkshire Hathaway', 'Conglomerate', '302,089', '9.4%',
#         '383,000', 'Omaha, Nebraska'],
#        [8, 'Alphabet', 'Technology and cloud computing', '282,836',
#         '9.8%', '156,000', 'Mountain View, California'],
#        [9, 'McKesson Corporation', 'Health', '276,711', '4.8%', '48,500',
# ...

# %%
import numpy as np 
np.ndim(array)
# Out:
# 2

# %%
np.size(array)
# Out:
# 700

# %% [markdown]
# conver the array into dataframe

# %%
df = pd.DataFrame(array , columns=df.columns)

# %%
df.head()
# Out:
#   Rank                Name                    Industry Revenue (USD millions)  \
# 0    1             Walmart                      Retail                611,289
# 1    2              Amazon  Retail and cloud computing                513,983
# 2    3          ExxonMobil          Petroleum industry                413,680
# 3    4               Apple        Electronics industry                394,328
# 4    5  UnitedHealth Group                  Healthcare                324,162
#
#   Revenue growth  Employees           Headquarters
# 0           6.7%  2,100,000  Bentonville, Arkansas
# 1           9.4%  1,540,000    Seattle, Washington
# 2          44.8%     62,000          Spring, Texas
# 3           7.8%    164,000  Cupertino, California
# 4          12.7%    400,000  Minnetonka, Minnesota

# %% [markdown]
# run the code of import data of csv

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Industry', 'Revenue (USD millions)', 'Revenue growth',
#        'Employees', 'Headquarters'],
#       dtype='object')
