# %% [markdown]
# > ## we want row number 1 with all its columnc

# %% [markdown]
# # default loc is used

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\user\Downloads\Companies.csv")

# %%
df[1:5] # default loc is used
# Out:
#    Rank                Name                    Industry  \
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 2                413,680          44.8%     62,000          Spring, Texas
# 3                394,328           7.8%    164,000  Cupertino, California
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %%
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                611,289           6.7%  2,100,000  Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 2                413,680          44.8%     62,000          Spring, Texas
# 3                394,328           7.8%    164,000  Cupertino, California
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %%
df.loc[0,:] # row number 1 with all its colmcs
# Out:
# Rank                                          1
# Name                                    Walmart
# Industry                                 Retail
# Revenue (USD millions)                  611,289
# Revenue growth                             6.7%
# Employees                             2,100,000
# Headquarters              Bentonville, Arkansas
# Name: 0, dtype: object

# %%
df.loc[56]
# Out:
# Rank                                  57
# Name                               Sysco
# Industry                    Food service
# Revenue (USD millions)            68,636
# Revenue growth                     33.8%
# Employees                         70,510
# Headquarters              Houston, Texas
# Name: 56, dtype: object

# %%
df.loc[[0,56,3], :]
# Out:
#     Rank     Name              Industry Revenue (USD millions) Revenue growth  \
# 0      1  Walmart                Retail                611,289           6.7%
# 56    57    Sysco          Food service                 68,636          33.8%
# 3      4    Apple  Electronics industry                394,328           7.8%
#
#     Employees           Headquarters
# 0   2,100,000  Bentonville, Arkansas
# 56     70,510         Houston, Texas
# 3     164,000  Cupertino, California

# %% [markdown]
# # All rows from 0 to n

# %%
df.loc[::-1]
# Out:
#     Rank                      Name                    Industry  \
# 99   100                  Qualcomm                  Technology
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 97    98           United Airlines                     Airline
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 95    96                  Best Buy                      Retail
# ..   ...                       ...                         ...
# 4      5        UnitedHealth Group                  Healthcare
# 3      4                     Apple        Electronics industry
# 2      3                ExxonMobil          Petroleum industry
# 1      2                    Amazon  Retail and cloud computing
# 0      1                   Walmart                      Retail
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 99                 44,200          31.7%     51,000    San Diego, California
# ...

# %% [markdown]
# ## -1 is not in the index because of that reason

# %% [markdown]
# # find the shape and give it to find the last element with loc

# %%
df.loc[-1, :]  # why can we not use the -1 in the start
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df.loc[-1, :]  # why can we not use the -1 in the start
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# ...

# %% [markdown]
# > ## slice by  col name

# %%
df.loc[10:50,"Name"]
# Out:
# 10                     Cencora
# 11                      Costco
# 12                   Microsoft
# 13             Cardinal Health
# 14                       Cigna
# 15          Marathon Petroleum
# 16                 Phillips 66
# 17               Valero Energy
# 18          Ford Motor Company
# 19              The Home Depot
# 20              General Motors
# 21             Elevance Health
# 22              JPMorgan Chase
# 23                      Kroger
# 24                     Centene
# 25      Verizon Communications
# 26    Walgreens Boots Alliance
# 27                  Fannie Mae
# 28                     Comcast
# 29                        AT&T
# 30              Meta Platforms
# 31             Bank of America
# 32          Target Corporation
# 33           Dell Technologies
# 34      Archer Daniels Midland
# 35                   Citigroup
# 36       United Parcel Service
# 37                      Pfizer
# 38                      Lowe's
# 39           Johnson & Johnson
# ...

# %%
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                611,289           6.7%  2,100,000  Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 2                413,680          44.8%     62,000          Spring, Texas
# 3                394,328           7.8%    164,000  Cupertino, California
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %%
df.loc[:,"Employees"]  # all datils of the employee columns
# Out:
# 0     2,100,000
# 1     1,540,000
# 2        62,000
# 3       164,000
# 4       400,000
#         ...
# 95       71,100
# 96       34,300
# 97       92,795
# 98      130,000
# 99       51,000
# Name: Employees, Length: 100, dtype: object

# %%
df.loc[:,"Name" :"Industry"]
# Out:
#                         Name                    Industry
# 0                    Walmart                      Retail
# 1                     Amazon  Retail and cloud computing
# 2                 ExxonMobil          Petroleum industry
# 3                      Apple        Electronics industry
# 4         UnitedHealth Group                  Healthcare
# ..                       ...                         ...
# 95                  Best Buy                      Retail
# 96      Bristol-Myers Squibb     Pharmaceutical industry
# 97           United Airlines                     Airline
# 98  Thermo Fisher Scientific      Laboratory instruments
# 99                  Qualcomm                  Technology
#
# [100 rows x 2 columns]

# %%
df.loc[:,"Name" : "Employees" ]
# Out:
#                         Name                    Industry  \
# 0                    Walmart                      Retail
# 1                     Amazon  Retail and cloud computing
# 2                 ExxonMobil          Petroleum industry
# 3                      Apple        Electronics industry
# 4         UnitedHealth Group                  Healthcare
# ..                       ...                         ...
# 95                  Best Buy                      Retail
# 96      Bristol-Myers Squibb     Pharmaceutical industry
# 97           United Airlines                     Airline
# 98  Thermo Fisher Scientific      Laboratory instruments
# 99                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees
# 0                 611,289           6.7%  2,100,000
# 1                 513,983           9.4%  1,540,000
# 2                 413,680          44.8%     62,000
# 3                 394,328           7.8%    164,000
# ...

# %% [markdown]
# ## all the two valuea re inclusive
# ### it will not follow the __n-1__ concept here

# %% [markdown]
# ### list must be give to be fetch

# %%
df[:2]
# Out:
#    Rank     Name                    Industry Revenue (USD millions)  \
# 0     1  Walmart                      Retail                611,289
# 1     2   Amazon  Retail and cloud computing                513,983
#
#   Revenue growth  Employees           Headquarters
# 0           6.7%  2,100,000  Bentonville, Arkansas
# 1           9.4%  1,540,000    Seattle, Washington

# %%
df.loc[:2]
# Out:
#    Rank        Name                    Industry Revenue (USD millions)  \
# 0     1     Walmart                      Retail                611,289
# 1     2      Amazon  Retail and cloud computing                513,983
# 2     3  ExxonMobil          Petroleum industry                413,680
#
#   Revenue growth  Employees           Headquarters
# 0           6.7%  2,100,000  Bentonville, Arkansas
# 1           9.4%  1,540,000    Seattle, Washington
# 2          44.8%     62,000          Spring, Texas

# %%
df.loc[0:50,["Name" , "Industry"]]

# %%
df.loc[:,"Name" : "Employees" ]   # why it is not stopping at 79
# Out:
#                         Name                    Industry  \
# 0                    Walmart                      Retail
# 1                     Amazon  Retail and cloud computing
# 2                 ExxonMobil          Petroleum industry
# 3                      Apple        Electronics industry
# 4         UnitedHealth Group                  Healthcare
# ..                       ...                         ...
# 95                  Best Buy                      Retail
# 96      Bristol-Myers Squibb     Pharmaceutical industry
# 97           United Airlines                     Airline
# 98  Thermo Fisher Scientific      Laboratory instruments
# 99                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees
# 0                 611,289           6.7%  2,100,000
# 1                 513,983           9.4%  1,540,000
# 2                 413,680          44.8%     62,000
# 3                 394,328           7.8%    164,000
# ...

# %% [markdown]
# > ## conditioning in the loc

# %%
df.loc[df.Industry == "Retail"  ]
# Out:
#     Rank                Name Industry Revenue (USD millions) Revenue growth  \
# 0      1             Walmart   Retail                611,289           6.7%
# 11    12              Costco   Retail                226,954          15.8%
# 19    20      The Home Depot   Retail                157,403           4.1%
# 23    24              Kroger   Retail                148,258           7.5%
# 32    33  Target Corporation   Retail                109,120           2.9%
# 38    39              Lowe's   Retail                 97,059           0.8%
# 52    53          Albertsons   Retail                 77,650           8.0%
# 79    80              Publix   Retail                 54,942          13.5%
# 88    89                 TJX   Retail                 49,936           2.9%
# 95    96            Best Buy   Retail                 46,298          10.6%
#
#     Employees                 Headquarters
# 0   2,100,000        Bentonville, Arkansas
# 11    304,000         Issaquah, Washington
# ...

# %%
#holw info of  that company whoes industry is retail
df.loc[df.Industry == "Retail" ]
# Out:
#     Rank                Name Industry Revenue (USD millions) Revenue growth  \
# 0      1             Walmart   Retail                611,289           6.7%
# 11    12              Costco   Retail                226,954          15.8%
# 19    20      The Home Depot   Retail                157,403           4.1%
# 23    24              Kroger   Retail                148,258           7.5%
# 32    33  Target Corporation   Retail                109,120           2.9%
# 38    39              Lowe's   Retail                 97,059           0.8%
# 52    53          Albertsons   Retail                 77,650           8.0%
# 79    80              Publix   Retail                 54,942          13.5%
# 88    89                 TJX   Retail                 49,936           2.9%
# 95    96            Best Buy   Retail                 46,298          10.6%
#
#     Employees                 Headquarters
# 0   2,100,000        Bentonville, Arkansas
# 11    304,000         Issaquah, Washington
# ...

# %% [markdown]
# > ###  name of that company whoes industry is retail

# %%
df.loc[df.Industry == "Retail","Name" ]
# Out:
# 0                Walmart
# 11                Costco
# 19        The Home Depot
# 23                Kroger
# 32    Target Corporation
# 38                Lowe's
# 52            Albertsons
# 79                Publix
# 88                   TJX
# 95              Best Buy
# Name: Name, dtype: object
